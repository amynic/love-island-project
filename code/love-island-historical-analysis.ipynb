# %%
#Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read CSV file
data = pd.read_csv('love-island-historical-dataset.csv')
#print(data)

# %%
shape = data.shape
print(shape)
columns = data.columns.tolist()
print(columns)
# Out:
# (96, 21)
# ['Contestant Name', 'OUTCOME', 'Day left Villa', 'Age', 'Profession', 'From', 'Area of UK', 'Gender', 'First Group to enter villa', 'Day Joined Villa', 'NUMBER OF DAYS IN VILLA', 'Number of Couples', 'Casa Amor addition', 'Times got Pied', 'Number of dates', 'Number of challenges won', 'Number of Bust Ups', 'Do Bits', 'Longest couple length', 'Was longest couple final couple', 'love-island-series']

# %%
winners = data[data['OUTCOME'].values == 'WINNER']
winners.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Contestant Name</th>
#         <th class="col_heading level0 col1" >OUTCOME</th>
#         <th class="col_heading level0 col2" >Day left Villa</th>
#         <th class="col_heading level0 col3" >Age</th>
#         <th class="col_heading level0 col4" >Profession</th>
#         <th class="col_heading level0 col5" >From</th>
#         <th class="col_heading level0 col6" >Area of UK</th>
#         <th class="col_heading level0 col7" >Gender</th>
#         <th class="col_heading level0 col8" >First Group to enter villa</th>
#         <th class="col_heading level0 col9" >Day Joined Villa</th>
#         <th class="col_heading level0 col10" >NUMBER OF DAYS IN VILLA</th>
#         <th class="col_heading level0 col11" >Number of Couples</th>
#         <th class="col_heading level0 col12" >Casa Amor addition</th>
#         <th class="col_heading level0 col13" >Times got Pied</th>
#         <th class="col_heading level0 col14" >Number of dates</th>
#         <th class="col_heading level0 col15" >Number of challenges won</th>
#         <th class="col_heading level0 col16" >Number of Bust Ups</th>
#         <th class="col_heading level0 col17" >Do Bits</th>
#         <th class="col_heading level0 col18" >Longest couple length</th>
#         <th class="col_heading level0 col19" >Was longest couple final couple</th>
#         <th class="col_heading level0 col20" >love-island-series</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col0" class="data row0 col0" >Cara De La Hoyde</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col1" class="data row0 col1" >WINNER</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col2" class="data row0 col2" >45</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col3" class="data row0 col3" >26</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col4" class="data row0 col4" >circus performer</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col5" class="data row0 col5" >Kent</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col6" class="data row0 col6" >South</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col7" class="data row0 col7" >female</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col8" class="data row0 col8" >YES</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col9" class="data row0 col9" >1</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col10" class="data row0 col10" >44</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col11" class="data row0 col11" >1</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col12" class="data row0 col12" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col13" class="data row0 col13" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col14" class="data row0 col14" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col15" class="data row0 col15" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col16" class="data row0 col16" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col17" class="data row0 col17" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col18" class="data row0 col18" >44</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col19" class="data row0 col19" >YES</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row0_col20" class="data row0 col20" >2016</td>
#     </tr>    <tr>
#         <th id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col0" class="data row1 col0" >Nathan Massey</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col1" class="data row1 col1" >WINNER</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col2" class="data row1 col2" >45</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col3" class="data row1 col3" >25</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col4" class="data row1 col4" >carpenter</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col5" class="data row1 col5" >Essex</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col6" class="data row1 col6" >South</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col7" class="data row1 col7" >male</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col8" class="data row1 col8" >YES</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col9" class="data row1 col9" >1</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col10" class="data row1 col10" >44</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col11" class="data row1 col11" >1</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col12" class="data row1 col12" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col13" class="data row1 col13" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col14" class="data row1 col14" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col15" class="data row1 col15" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col16" class="data row1 col16" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col17" class="data row1 col17" >nan</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col18" class="data row1 col18" >44</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col19" class="data row1 col19" >YES</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row1_col20" class="data row1 col20" >2016</td>
#     </tr>    <tr>
#         <th id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5level0_row2" class="row_heading level0 row2" >26</th>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col0" class="data row2 col0" >Amber Davis</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col1" class="data row2 col1" >WINNER</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col2" class="data row2 col2" >52</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col3" class="data row2 col3" >20</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col4" class="data row2 col4" >dancer</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col5" class="data row2 col5" >Wales</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col6" class="data row2 col6" >Wales</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col7" class="data row2 col7" >female</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col8" class="data row2 col8" >YES</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col9" class="data row2 col9" >1</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col10" class="data row2 col10" >51</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col11" class="data row2 col11" >5</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col12" class="data row2 col12" >NO</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col13" class="data row2 col13" >2</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col14" class="data row2 col14" >5</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col15" class="data row2 col15" >0</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col16" class="data row2 col16" >2</td>
#         <td id="T_eac5384c_92a2_11e9_aac3_00155d83b5a5row2_col17" class="data row2

# %%
winners = data[data['OUTCOME'].values == 'RUNNER UP']
winners.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Contestant Name</th>
#         <th class="col_heading level0 col1" >OUTCOME</th>
#         <th class="col_heading level0 col2" >Day left Villa</th>
#         <th class="col_heading level0 col3" >Age</th>
#         <th class="col_heading level0 col4" >Profession</th>
#         <th class="col_heading level0 col5" >From</th>
#         <th class="col_heading level0 col6" >Area of UK</th>
#         <th class="col_heading level0 col7" >Gender</th>
#         <th class="col_heading level0 col8" >First Group to enter villa</th>
#         <th class="col_heading level0 col9" >Day Joined Villa</th>
#         <th class="col_heading level0 col10" >NUMBER OF DAYS IN VILLA</th>
#         <th class="col_heading level0 col11" >Number of Couples</th>
#         <th class="col_heading level0 col12" >Casa Amor addition</th>
#         <th class="col_heading level0 col13" >Times got Pied</th>
#         <th class="col_heading level0 col14" >Number of dates</th>
#         <th class="col_heading level0 col15" >Number of challenges won</th>
#         <th class="col_heading level0 col16" >Number of Bust Ups</th>
#         <th class="col_heading level0 col17" >Do Bits</th>
#         <th class="col_heading level0 col18" >Longest couple length</th>
#         <th class="col_heading level0 col19" >Was longest couple final couple</th>
#         <th class="col_heading level0 col20" >love-island-series</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5level0_row0" class="row_heading level0 row0" >2</th>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col0" class="data row0 col0" >Alex Bowen</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col1" class="data row0 col1" >RUNNER UP</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col2" class="data row0 col2" >45</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col3" class="data row0 col3" >24</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col4" class="data row0 col4" >model</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col5" class="data row0 col5" >Birmingham</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col6" class="data row0 col6" >Midlands</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col7" class="data row0 col7" >male</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col8" class="data row0 col8" >NO</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col9" class="data row0 col9" >18</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col10" class="data row0 col10" >27</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col11" class="data row0 col11" >1</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col12" class="data row0 col12" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col13" class="data row0 col13" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col14" class="data row0 col14" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col15" class="data row0 col15" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col16" class="data row0 col16" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col17" class="data row0 col17" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col18" class="data row0 col18" >25</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col19" class="data row0 col19" >YES</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row0_col20" class="data row0 col20" >2016</td>
#     </tr>    <tr>
#         <th id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5level0_row1" class="row_heading level0 row1" >3</th>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col0" class="data row1 col0" >Olivia Buckland</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col1" class="data row1 col1" >RUNNER UP</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col2" class="data row1 col2" >45</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col3" class="data row1 col3" >22</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col4" class="data row1 col4" >sales executive</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col5" class="data row1 col5" >Essex</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col6" class="data row1 col6" >South</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col7" class="data row1 col7" >female</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col8" class="data row1 col8" >YES</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col9" class="data row1 col9" >1</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col10" class="data row1 col10" >44</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col11" class="data row1 col11" >4</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col12" class="data row1 col12" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col13" class="data row1 col13" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col14" class="data row1 col14" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col15" class="data row1 col15" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col16" class="data row1 col16" >1</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col17" class="data row1 col17" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col18" class="data row1 col18" >25</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col19" class="data row1 col19" >YES</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row1_col20" class="data row1 col20" >2016</td>
#     </tr>    <tr>
#         <th id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5level0_row2" class="row_heading level0 row2" >28</th>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col0" class="data row2 col0" >Camilla Thurlow</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col1" class="data row2 col1" >RUNNER UP</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col2" class="data row2 col2" >52</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col3" class="data row2 col3" >27</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col4" class="data row2 col4" >explosive ordance disposal</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col5" class="data row2 col5" >Scotland</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col6" class="data row2 col6" >Scotland</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col7" class="data row2 col7" >female</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col8" class="data row2 col8" >YES</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col9" class="data row2 col9" >1</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col10" class="data row2 col10" >51</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col11" class="data row2 col11" >4</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col12" class="data row2 col12" >NO</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col13" class="data row2 col13" >2</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col14" class="data row2 col14" >7</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col15" class="data row2 col15" >1</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00155d83b5a5row2_col16" class="data row2 col16" >nan</td>
#         <td id="T_ead0015a_92a2_11e9_aac3_00

# %%
winners = data[data['OUTCOME'].values == 'THIRD PLACE']
winners.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Contestant Name</th>
#         <th class="col_heading level0 col1" >OUTCOME</th>
#         <th class="col_heading level0 col2" >Day left Villa</th>
#         <th class="col_heading level0 col3" >Age</th>
#         <th class="col_heading level0 col4" >Profession</th>
#         <th class="col_heading level0 col5" >From</th>
#         <th class="col_heading level0 col6" >Area of UK</th>
#         <th class="col_heading level0 col7" >Gender</th>
#         <th class="col_heading level0 col8" >First Group to enter villa</th>
#         <th class="col_heading level0 col9" >Day Joined Villa</th>
#         <th class="col_heading level0 col10" >NUMBER OF DAYS IN VILLA</th>
#         <th class="col_heading level0 col11" >Number of Couples</th>
#         <th class="col_heading level0 col12" >Casa Amor addition</th>
#         <th class="col_heading level0 col13" >Times got Pied</th>
#         <th class="col_heading level0 col14" >Number of dates</th>
#         <th class="col_heading level0 col15" >Number of challenges won</th>
#         <th class="col_heading level0 col16" >Number of Bust Ups</th>
#         <th class="col_heading level0 col17" >Do Bits</th>
#         <th class="col_heading level0 col18" >Longest couple length</th>
#         <th class="col_heading level0 col19" >Was longest couple final couple</th>
#         <th class="col_heading level0 col20" >love-island-series</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5level0_row0" class="row_heading level0 row0" >4</th>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col0" class="data row0 col0" >Kady McDermott</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col1" class="data row0 col1" >THIRD PLACE</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col2" class="data row0 col2" >45</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col3" class="data row0 col3" >20</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col4" class="data row0 col4" >makeup artist</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col5" class="data row0 col5" >Stevenage</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col6" class="data row0 col6" >South</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col7" class="data row0 col7" >female</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col8" class="data row0 col8" >NO</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col9" class="data row0 col9" >3</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col10" class="data row0 col10" >42</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col11" class="data row0 col11" >1</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col12" class="data row0 col12" >nan</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col13" class="data row0 col13" >nan</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col14" class="data row0 col14" >nan</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col15" class="data row0 col15" >nan</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col16" class="data row0 col16" >2</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col17" class="data row0 col17" >nan</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col18" class="data row0 col18" >39</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col19" class="data row0 col19" >YES</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row0_col20" class="data row0 col20" >2016</td>
#     </tr>    <tr>
#         <th id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5level0_row1" class="row_heading level0 row1" >5</th>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col0" class="data row1 col0" >Scott Thomas</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col1" class="data row1 col1" >THIRD PLACE</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col2" class="data row1 col2" >45</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col3" class="data row1 col3" >28</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col4" class="data row1 col4" >nightclub promoter</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col5" class="data row1 col5" >Manchester</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col6" class="data row1 col6" >North</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col7" class="data row1 col7" >male</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col8" class="data row1 col8" >YES</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col9" class="data row1 col9" >1</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col10" class="data row1 col10" >44</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col11" class="data row1 col11" >2</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col12" class="data row1 col12" >nan</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col13" class="data row1 col13" >nan</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col14" class="data row1 col14" >nan</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col15" class="data row1 col15" >nan</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col16" class="data row1 col16" >1</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col17" class="data row1 col17" >nan</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col18" class="data row1 col18" >39</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col19" class="data row1 col19" >YES</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row1_col20" class="data row1 col20" >2016</td>
#     </tr>    <tr>
#         <th id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5level0_row2" class="row_heading level0 row2" >30</th>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col0" class="data row2 col0" >Chris Hughes</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col1" class="data row2 col1" >THIRD PLACE</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col2" class="data row2 col2" >52</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col3" class="data row2 col3" >24</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col4" class="data row2 col4" >golf clothing ambassador</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col5" class="data row2 col5" >Cheltenham</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col6" class="data row2 col6" >Midlands</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col7" class="data row2 col7" >male</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col8" class="data row2 col8" >NO</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col9" class="data row2 col9" >4</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col10" class="data row2 col10" >48</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col11" class="data row2 col11" >2</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col12" class="data row2 col12" >NO</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col13" class="data row2 col13" >1</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col14" class="data row2 col14" >7</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col15" class="data row2 col15" >2</td>
#         <td id="T_eaddcf2e_92a2_11e9_aac3_00155d83b5a5row2_col16" class="data row2 col16" >2</td>
#         <td id="T_eaddcf2e_92a2_11e9

# %% [markdown]
# # Graphs

# %%
#simple histogram
ages = data['Age']
plt.hist(ages, 12, histtype='stepfilled', color='purple')
# Out:
# (array([ 2., 10.,  8., 16., 15.,  8., 14.,  9.,  6.,  4.,  1.,  3.]),
#  array([18.        , 19.08333333, 20.16666667, 21.25      , 22.33333333,
#         23.41666667, 24.5       , 25.58333333, 26.66666667, 27.75      ,
#         28.83333333, 29.91666667, 31.        ]),
#  <a list of 1 Patch objects>)

# %%
# main dataset
daysinvilla = data[['Contestant Name','NUMBER OF DAYS IN VILLA', 'love-island-series', 'First Group to enter villa']]

# Split data by love island series
year2018 = daysinvilla[daysinvilla['love-island-series'].values == 2018].sort_values('NUMBER OF DAYS IN VILLA')
year2017 = daysinvilla[daysinvilla['love-island-series'].values == 2017].sort_values('NUMBER OF DAYS IN VILLA')
year2016 = daysinvilla[daysinvilla['love-island-series'].values == 2016].sort_values('NUMBER OF DAYS IN VILLA')


# Plot all data on sub plot graphs
fig, axs = plt.subplots(2, 2, figsize=(20, 20))
axs[0, 0].barh(year2018['Contestant Name'], year2018['NUMBER OF DAYS IN VILLA'],height= 0.8)
axs[1, 0].barh(year2017['Contestant Name'], year2017['NUMBER OF DAYS IN VILLA'],height= 0.8)
axs[0, 1].barh(year2016['Contestant Name'], year2016['NUMBER OF DAYS IN VILLA'],height= 0.8)
# Out:
# <BarContainer object of 26 artists>

# %%
# simple pie charts
areaofuk = data['Area of UK'].value_counts()
destination = data['From'].value_counts()
print(areaofuk)
plt.pie(areaofuk, labels = areaofuk.index)
# Out:
# South       57
# North       21
# Midlands     9
# Wales        4
# Ireland      3
# Scotland     2
# Name: Area of UK, dtype: int64
# ([<matplotlib.patches.Wedge at 0x7f839a8db160>,
#   <matplotlib.patches.Wedge at 0x7f839a8db6d8>,
#   <matplotlib.patches.Wedge at 0x7f839a8dbba8>,
#   <matplotlib.patches.Wedge at 0x7f839a8e60b8>,
#   <matplotlib.patches.Wedge at 0x7f839a8e6588>,
#   <matplotlib.patches.Wedge at 0x7f839a8e6a58>],
#  [Text(-0.3193131449799084, 1.0526343693054299, 'South'),
#   Text(-0.3193131449799087, -1.0526343693054299, 'North'),
#   Text(0.6978326125800102, -0.8503114986990107, 'Midlands'),
#   Text(0.9865600175839181, -0.4865175553922175, 'Wales'),
#   Text(1.0712646791539384, -0.24978388097955784, 'Ireland'),
#   Text(1.097644816264113, -0.07194343144806095, 'Scotland')])

# %%
# % chance given historical data
first_to_enter_villa = len(data['First Group to enter villa'])
first_to_enter_villa_yes = len(data[data['First Group to enter villa'].values == 'YES'])
first_to_enter_villa_no = len(data[data['First Group to enter villa'].values == 'NO'])

first_villa = data[(data['First Group to enter villa'].values == 'YES')]
winner = data[data['OUTCOME'].values == 'WINNER']
runnerup = data[data['OUTCOME'].values == 'RUNNER UP']
thirdplace = data[data['OUTCOME'].values == 'THIRD PLACE']
first_villa_and_winner = data[(data['First Group to enter villa'].values == 'YES')&(data['OUTCOME'].values == 'WINNER')]
first_villa_and_runnerup = data[(data['First Group to enter villa'].values == 'YES')&(data['OUTCOME'].values == 'RUNNER UP')]
first_villa_and_thirdplace = data[(data['First Group to enter villa'].values == 'YES')&(data['OUTCOME'].values == 'THIRD PLACE')]



percent_first_villa_and_winner = (len(first_villa_and_winner)/len(winner))*100
print('Percentage of poeple who won and were part of the first group to enter the villa: '+ str(percent_first_villa_and_winner) + '%')

percent_first_villa_inc_runnerup = ((len(first_villa_and_winner)+(len(first_villa_and_runnerup)))/(len(winner)+len(runnerup)))*100
print('Percentage of poeple who won/runner up and were part of the first group to enter the villa: ' + str(percent_first_villa_inc_runnerup) + '%')

percent_first_villa_inc_thirdplace = ((len(first_villa_and_winner)+len(first_villa_and_runnerup)+len(first_villa_and_thirdplace))/(len(winner)+len(runnerup)+len(thirdplace)))*100
print('Percentage of poeple who won/runner up/third place and were part of the first group to enter the villa: ' + str(percent_first_villa_inc_thirdplace) + '%')
# Out:
# Percentage of poeple who won and were part of the first group to enter the villa: 100.0%
# Percentage of poeple who won/runner up and were part of the first group to enter the villa: 75.0%
# Percentage of poeple who won/runner up/third place and were part of the first group to enter the villa: 61.111111111111114%

# %%
columns = data.columns.tolist()
print(columns)
# Out:
# ['Contestant Name', 'OUTCOME', 'Day left Villa', 'Age', 'Profession', 'From', 'Area of UK', 'Gender', 'First Group to enter villa', 'Day Joined Villa', 'NUMBER OF DAYS IN VILLA', 'Number of Couples', 'Casa Amor addition', 'Times got Pied', 'Number of dates', 'Number of challenges won', 'Number of Bust Ups', 'Do Bits', 'Longest couple length', 'Was longest couple final couple', 'love-island-series']

# %%
#Scatter Plot - day joined villa / no of couple
x1 = data['Day Joined Villa']
y1 = data['Number of Couples']
x2 = data['Age']
y2 = data['Longest couple length']
y3 = data['NUMBER OF DAYS IN VILLA']
y4 = data['Day left Villa']



data_2018 = data[data['love-island-series'] >= 2018]
#print(times_got_pied_days_in_villa_2018)
x5 = data_2018['NUMBER OF DAYS IN VILLA']
y5 = data_2018['Times got Pied']
y6 = data_2018['Number of dates']
y7 = data_2018['Number of Bust Ups']

# %%
plt.figure(figsize=(10,10))
plt.scatter(x1,y1)
plt.xlabel("Day entered the Villa")
plt.ylabel("Number of couples")
plt.title('Day Contestant Joined the Villa by Number of Couples they had - trending down')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(x2,y1)
plt.xlabel("Age")
plt.ylabel("Number of couples")
plt.title('A graph to show how age relates to Number of couples across the show')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(x2,y4)
plt.xlabel("Age")
plt.ylabel("Day left the Villa")
plt.title('No correlation shown between leaving the villa and age')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(x5,y6)
plt.xlabel("Number of days in Villa")
plt.ylabel("Number of times pied")
#plt.title('No correlation shown between leaving the villa and age')
plt.show()
